# %% [markdown]
# # Stock prediction of Netflix using LSTM

# %%
#importing libraries to be used
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') 
from sklearn.preprocessing import MinMaxScaler 
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv("C:/Users/USER/Downloads/NFLX.csv") # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 5  2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 6  2018-02-13  257.290009  261.410004  254.699997  258.269989  258.269989
# 7  2018-02-14  260.470001  269.880005  260.329987  266.000000  266.000000
# 8  2018-02-15  270.029999  280.500000  267.630005  280.269989  280.269989
# 9  2018-02-16  278.730011  281.959991  275.690002  278.519989  278.519989
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900
# 5   8534900
# 6   6855200
# 7  10972000
# 8  10759700
# 9   8312400

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1009, 7)

# %%
# statistical description of data
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Check for required columns
df = df[['Date','Open','Close']] 

# converting object dtype of date column to datetime dtype
df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split()[0]))

# %%
# setting date as index column
df.set_index('Date',drop=True,inplace=True) 
df.head(10)
# Out:
#                   Open       Close
# Date
# 2018-02-05  262.000000  254.259995
# 2018-02-06  247.699997  265.720001
# 2018-02-07  266.579987  264.559998
# 2018-02-08  267.079987  250.100006
# 2018-02-09  253.850006  249.470001
# 2018-02-12  252.139999  257.950012
# 2018-02-13  257.290009  258.269989
# 2018-02-14  260.470001  266.000000
# 2018-02-15  270.029999  280.269989
# 2018-02-16  278.730011  278.519989

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['Open'],label='Open',color='red')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].set_title('Opening Price',size=18)
ax[0].legend()

ax[1].plot(df['Close'],label='Close',color='orange')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].set_title('Closing Price',size=18)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 Open     Close
# Date
# 2018-02-05  0.061253  0.044516
# 2018-02-06  0.030059  0.069548
# 2018-02-07  0.071243  0.067015
# 2018-02-08  0.072334  0.035430
# 2018-02-09  0.043474  0.034053
# 2018-02-12  0.039744  0.052576
# 2018-02-13  0.050978  0.053275
# 2018-02-14  0.057915  0.070160
# 2018-02-15  0.078769  0.101330
# 2018-02-16  0.097747  0.097508

# %%
# splitting the data into train and test set
# Select 80% for train and 20% for test
training_size = round(len(df) * 0.80)

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((807, 2), (202, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((757, 50, 2), (757, 2), (152, 50, 2), (152, 2))

# %%
# imported Sequential from keras.models
model = Sequential()

# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=25, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=25))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 25)            2800
#
#  dropout (Dropout)           (None, 50, 25)            0
#
#  lstm_1 (LSTM)               (None, 25)                5100
#
#  dense (Dense)               (None, 2)                 52
#
# =================================================================
# Total params: 7952 (31.06 KB)
# Trainable params: 7952 (31.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 17s 214ms/step - loss: 0.0492 - mean_absolute_error: 0.1659 - val_loss: 0.0156 - val_mean_absolute_error: 0.0943
# Epoch 2/100
# 23/23 [==============================] - 1s 60ms/step - loss: 0.0058 - mean_absolute_error: 0.0593 - val_loss: 0.0105 - val_mean_absolute_error: 0.0768
# Epoch 3/100
# 23/23 [==============================] - 1s 59ms/step - loss: 0.0031 - mean_absolute_error: 0.0433 - val_loss: 0.0086 - val_mean_absolute_error: 0.0652
# Epoch 4/100
# 23/23 [==============================] - 1s 57ms/step - loss: 0.0026 - mean_absolute_error: 0.0395 - val_loss: 0.0072 - val_mean_absolute_error: 0.0587
# Epoch 5/100
# 23/23 [==============================] - 1s 58ms/step - loss: 0.0025 - mean_absolute_error: 0.0386 - val_loss: 0.0068 - val_mean_absolute_error: 0.0574
# Epoch 6/100
# 23/23 [==============================] - 1s 60ms/step - loss: 0.0025 - mean_absolute_error: 0.0384 - val_loss: 0.0067 - val_mean_absolute_error: 0.0566
# Epoch 7/100
# 23/23 [==============================] - 1s 56ms/step - loss: 0.0024 - mean_absolute_error: 0.0379 - val_loss: 0.0064 - val_mean_absolute_error: 0.0554
# Epoch 8/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0023 - mean_absolute_error: 0.0368 - val_loss: 0.0067 - val_mean_absolute_error: 0.0556
# Epoch 9/100
# 23/23 [==============================] - 1s 56ms/step - loss: 0.0023 - mean_absolute_error: 0.0370 - val_loss: 0.0060 - val_mean_absolute_error: 0.0535
# Epoch 10/100
# 23/23 [==============================] - 1s 61ms/step - loss: 0.0023 - mean_absolute_error: 0.0362 - val_loss: 0.0064 - val_mean_absolute_error: 0.0545
# Epoch 11/100
# 23/23 [==============================] - 1s 59ms/step - loss: 0.0022 - mean_absolute_error: 0.0351 - val_loss: 0.0055 - val_mean_absolute_error: 0.0517
# Epoch 12/100
# 23/23 [==============================] - 2s 72ms/step - loss: 0.0021 - mean_absolute_error: 0.0350 - val_loss: 0.0055 - val_mean_absolute_error: 0.0525
# Epoch 13/100
# 23/23 [==============================] - 1s 57ms/step - loss: 0.0022 - mean_absolute_error: 0.0357 - val_loss: 0.0052 - val_mean_absolute_error: 0.0509
# Epoch 14/100
# 23/23 [==============================] - 1s 60ms/step - loss: 0.0021 - mean_absolute_error: 0.0345 - val_loss: 0.0068 - val_mean_absolute_error: 0.0647
# Epoch 15/100
# 23/23 [==============================] - 1s 56ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0053 - val_mean_absolute_error: 0.0524
# Epoch 16/100
# 23/23 [==============================] - 1s 57ms/step - loss: 0.0021 - mean_absolute_error: 0.0342 - val_loss: 0.0060 - val_mean_absolute_error: 0.0595
# Epoch 17/100
# 23/23 [==============================] - 2s 68ms/step - loss: 0.0021 - mean_absolute_error: 0.0347 - val_loss: 0.0046 - val_mean_absolute_error: 0.0461
# Epoch 18/100
# 23/23 [==============================] - 1s 61ms/step - loss: 0.0020 - mean_absolute_error: 0.0335 - val_loss: 0.0045 - val_mean_absolute_error: 0.0465
# Epoch 19/100
# 23/23 [==============================] - 1s 58ms/step - loss: 0.0019 - mean_absolute_error: 0.0332 - val_loss: 0.0044 - val_mean_absolute_error: 0.0450
# Epoch 20/100
# 23/23 [==============================] - 1s 62ms/step - loss: 0.0018 - mean_absolute_error: 0.0323 - val_loss: 0.0042 - val_mean_absolute_error: 0.0438
# Epoch 21/100
# 23/23 [==============================] - 1s 58ms/step - loss: 0.0019 - mean_absolute_error: 0.0328 - val_loss: 0.0040 - val_mean_absolute_error: 0.0432
# Epoch 22/100
# 23/23 [==============================] - 1s 59ms/step - loss: 0.0018 - mean_absolute_error: 0.0320 - val_loss: 0.0052 - val_mean_absolute_error: 0.0554
# Epoch 23/100
# 23/23 [==============================] - 1s 56ms/step - loss: 0.0018 - mean_absolute_error: 0.0316 - val_loss: 0.0042 - val_mean_absolute_error: 0.0457
# Epoch 24/100
# 23/23 [==============================] - 1s 63ms/step - loss: 0.0018 - mean_absolute_error: 0.0308 - val_loss: 0.0042 - val_mean_absolute_error: 0.0466
# Epoch 25/100
# 23/23 [==============================] - 1s 58ms/step - loss: 0.0017 - mean_absolute_error: 0.0306 - val_loss: 0.0040 - val_mean_absolute_error: 0.0452
# Epoch 26/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0017 - mean_absolute_error: 0.0309 - val_loss: 0.0038 - val_mean_absolute_error: 0.0424
# Epoch 27/100
# 23/23 [==============================] - 2s 68ms/step - loss: 0.0016 - mean_absolute_error: 0.0306 - val_loss: 0.0037 - val_mean_absolute_error: 0.0415
# Epoch 28/100
# 23/23 [==============================] - 2s 78ms/step - loss: 0.0017 - mean_absolute_error: 0.0304 - val_loss: 0.0062 - val_mean_absolute_error: 0.0627
# Epoch 29/100
# 23/23 [==============================] - 1s 61ms/step - loss: 0.0018 - mean_absolute_error: 0.0315 - val_loss: 0.0037 - val_mean_absolute_error: 0.0421
# Epoch 30/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0016 - mean_absolute_error: 0.0297 - val_loss: 0.0040 - val_mean_absolute_error: 0.0450
# Epoch 31/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0015 - mean_absolute_error: 0.0299 - val_loss: 0.0045 - val_mean_absolute_error: 0.0493
# Epoch 32/100
# 23/23 [==============================] - 1s 57ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0038 - val_mean_absolute_error: 0.0432
# Epoch 33/100
# 23/23 [==============================] - 1s 57ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 0.0035 - val_mean_absolute_error: 0.0412
# Epoch 34/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0014 - mean_absolute_error: 0.0280 - val_loss: 0.0044 - val_mean_absolute_error: 0.0480
# Epoch 35/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 0.0037 - val_mean_absolute_error: 0.0423
# Epoch 36/100
# 23/23 [==============================] - 1s 53ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 0.0040 - val_mean_absolute_error: 0.0448
# Epoch 37/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0013 - mean_absolute_error: 0.0275 - val_loss: 0.0044 - val_mean_absolute_error: 0.0475
# Epoch 38/100
# 23/23 [==============================] - 1s 57ms/step - loss: 0.0013 - mean_absolute_error: 0.0265 - val_loss: 0.0041 - val_mean_absolute_error: 0.0460
# Epoch 39/100
# 23/23 [==============================] - 1s 58ms/step - loss: 0.0013 - mean_absolute_error: 0.0266 - val_loss: 0.0037 - val_mean_absolute_error: 0.0437
# Epoch 40/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0012 - mean_absolute_error: 0.0262 - val_loss: 0.0064 - val_mean_absolute_error: 0.0602
# Epoch 41/100
# 23/23 [==============================] - 1s 53ms/step - loss: 0.0012 - mean_absolute_error: 0.0264 - val_loss: 0.0041 - val_mean_absolute_error: 0.0467
# Epoch 42/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - val_loss: 0.0051 - val_mean_absolute_error: 0.0518
# Epoch 43/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0012 - mean_absolute_error: 0.0255 - val_loss: 0.0056 - val_mean_absolute_error: 0.0548
# Epoch 44/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0011 - mean_absolute_error: 0.0252 - val_loss: 0.0058 - val_mean_absolute_error: 0.0571
# Epoch 45/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 0.0060 - val_mean_absolute_error: 0.0594
# Epoch 46/100
# 23/23 [==============================] - 1s 57ms/step - loss: 0.0011 - mean_absolute_error: 0.0256 - val_loss: 0.0041 - val_mean_absolute_error: 0.0461
# Epoch 47/100
# 23/23 [==============================] - 1s 53ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 0.0046 - val_mean_absolute_error: 0.0500
# Epoch 48/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0011 - mean_absolute_error: 0.0243 - val_loss: 0.0055 - val_mean_absolute_error: 0.0545
# Epoch 49/100
# 23/23 [==============================] - 1s 56ms/step - loss: 0.0010 - mean_absolute_error: 0.0243 - val_loss: 0.0074 - val_mean_absolute_error: 0.0664
# Epoch 50/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.0011 - mean_absolute_error: 0.0252 - val_loss: 0.0071 - val_mean_absolute_error: 0.0640
# Epoch 51/100
# 23/23 [==============================] - 1s 55ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - val_loss: 0.0043 - val_mean_absolute_error: 0.0482
# Epoch 52/100
# 23/23 [==============================] - 1s 53ms/step - loss: 9.8459e-04 - mean_absolute_error: 0.0238 - val_loss: 0.0052 - val_mean_absolute_error: 0.0525
# Epoch 53/100
# 23/23 [==============================] - 1s 55ms/step - loss: 9.0892e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0050 - val_mean_absolute_error: 0.0516
# Epoch 54/100
# 23/23 [==============================] - 1s 52ms/step - loss: 9.2425e-04 - mean_absolute_error: 0.0222 - val_loss: 0.0058 - val_mean_absolute_error: 0.0559
# Epoch 55/100
# 23/23 [==============================] - 1s 53ms/step - loss: 9.5024e-04 - mean_absolute_error: 0.0230 - val_loss: 0.0075 - val_mean_absolute_error: 0.0652
# Epoch 56/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 0.0044 - val_mean_absolute_error: 0.0484
# Epoch 57/100
# 23/23 [==============================] - 1s 54ms/step - loss: 9.7899e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0037 - val_mean_absolute_error: 0.0456
# Epoch 58/100
# 23/23 [==============================] - 1s 64ms/step - loss: 8.8257e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0038 - val_mean_absolute_error: 0.0462
# Epoch 59/100
# 23/23 [==============================] - 1s 59ms/step - loss: 9.3126e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0042 - val_mean_absolute_error: 0.0482
# Epoch 60/100
# 23/23 [==============================] - 1s 57ms/step - loss: 9.2174e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0048 - val_mean_absolute_error: 0.0507
# Epoch 61/100
# 23/23 [==============================] - 1s 55ms/step - loss: 8.1900e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0055 - val_mean_absolute_error: 0.0546
# Epoch 62/100
# 23/23 [==============================] - 1s 53ms/step - loss: 7.9141e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0053 - val_mean_absolute_error: 0.0533
# Epoch 63/100
# 23/23 [==============================] - 1s 55ms/step - loss: 8.3220e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0043 - val_mean_absolute_error: 0.0485
# Epoch 64/100
# 23/23 [==============================] - 2s 73ms/step - loss: 8.2723e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0036 - val_mean_absolute_error: 0.0454
# Epoch 65/100
# 23/23 [==============================] - 1s 64ms/step - loss: 7.8889e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0040 - val_mean_absolute_error: 0.0468
# Epoch 66/100
# 23/23 [==============================] - 2s 68ms/step - loss: 7.2127e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0050 - val_mean_absolute_error: 0.0525
# Epoch 67/100
# 23/23 [==============================] - 1s 59ms/step - loss: 8.2836e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0062 - val_mean_absolute_error: 0.0600
# Epoch 68/100
# 23/23 [==============================] - 1s 56ms/step - loss: 7.4921e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0052 - val_mean_absolute_error: 0.0530
# Epoch 69/100
# 23/23 [==============================] - 1s 60ms/step - loss: 7.2073e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0051 - val_mean_absolute_error: 0.0524
# Epoch 70/100
# 23/23 [==============================] - 1s 55ms/step - loss: 6.8104e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0041 - val_mean_absolute_error: 0.0482
# Epoch 71/100
# 23/23 [==============================] - 1s 56ms/step - loss: 6.8575e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0052 - val_mean_absolute_error: 0.0532
# Epoch 72/100
# 23/23 [==============================] - 1s 57ms/step - loss: 7.3558e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0034 - val_mean_absolute_error: 0.0425
# Epoch 73/100
# 23/23 [==============================] - 1s 58ms/step - loss: 7.6760e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0055 - val_mean_absolute_error: 0.0549
# Epoch 74/100
# 23/23 [==============================] - 1s 59ms/step - loss: 7.1667e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0058 - val_mean_absolute_error: 0.0587
# Epoch 75/100
# 23/23 [==============================] - 1s 55ms/step - loss: 7.0245e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0054 - val_mean_absolute_error: 0.0568
# Epoch 76/100
# 23/23 [==============================] - 1s 52ms/step - loss: 7.3320e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0051 - val_mean_absolute_error: 0.0536
# Epoch 77/100
# 23/23 [==============================] - 1s 55ms/step - loss: 6.7129e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0057 - val_mean_absolute_error: 0.0589
# Epoch 78/100
# 23/23 [==============================] - 1s 54ms/step - loss: 7.3460e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0048 - val_mean_absolute_error: 0.0528
# Epoch 79/100
# 23/23 [==============================] - 1s 59ms/step - loss: 6.9731e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0048 - val_mean_absolute_error: 0.0520
# Epoch 80/100
# 23/23 [==============================] - 1s 54ms/step - loss: 6.3758e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0031 - val_mean_absolute_error: 0.0406
# Epoch 81/100
# 23/23 [==============================] - 1s 52ms/step - loss: 6.3930e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0043 - val_mean_absolute_error: 0.0487
# Epoch 82/100
# 23/23 [==============================] - 1s 52ms/step - loss: 7.6125e-04 - mean_absolute_error: 0.0209 - val_loss: 0.0043 - val_mean_absolute_error: 0.0491
# Epoch 83/100
# 23/23 [==============================] - 1s 55ms/step - loss: 6.1477e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0039 - val_mean_absolute_error: 0.0467
# Epoch 84/100
# 23/23 [==============================] - 1s 58ms/step - loss: 6.5320e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0029 - val_mean_absolute_error: 0.0392
# Epoch 85/100
# 23/23 [==============================] - 1s 51ms/step - loss: 6.5497e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0029 - val_mean_absolute_error: 0.0400
# Epoch 86/100
# 23/23 [==============================] - 1s 52ms/step - loss: 7.1110e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0032 - val_mean_absolute_error: 0.0408
# Epoch 87/100
# 23/23 [==============================] - 1s 52ms/step - loss: 5.9577e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0041 - val_mean_absolute_error: 0.0471
# Epoch 88/100
# 23/23 [==============================] - 1s 51ms/step - loss: 5.7347e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0038 - val_mean_absolute_error: 0.0459
# Epoch 89/100
# 23/23 [==============================] - 1s 49ms/step - loss: 6.3097e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0046 - val_mean_absolute_error: 0.0527
# Epoch 90/100
# 23/23 [==============================] - 1s 52ms/step - loss: 5.9943e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0032 - val_mean_absolute_error: 0.0411
# Epoch 91/100
# 23/23 [==============================] - 1s 58ms/step - loss: 5.7786e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0026 - val_mean_absolute_error: 0.0367
# Epoch 92/100
# 23/23 [==============================] - 2s 74ms/step - loss: 5.6528e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0028 - val_mean_absolute_error: 0.0385
# Epoch 93/100
# 23/23 [==============================] - 1s 63ms/step - loss: 5.6838e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0031 - val_mean_absolute_error: 0.0406
# Epoch 94/100
# 23/23 [==============================] - 1s 59ms/step - loss: 5.6786e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0033 - val_mean_absolute_error: 0.0423
# Epoch 95/100
# 23/23 [==============================] - 1s 55ms/step - loss: 6.0522e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0030 - val_mean_absolute_error: 0.0398
# Epoch 96/100
# 23/23 [==============================] - 1s 54ms/step - loss: 5.5079e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0027 - val_mean_absolute_error: 0.0374
# Epoch 97/100
# 23/23 [==============================] - 1s 57ms/step - loss: 5.1419e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0032 - val_mean_absolute_error: 0.0413
# Epoch 98/100
# 23/23 [==============================] - 1s 58ms/step - loss: 5.3044e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0031 - val_mean_absolute_error: 0.0411
# Epoch 99/100
# 23/23 [==============================] - 1s 62ms/step - loss: 5.4849e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0042 - val_mean_absolute_error: 0.0500
# Epoch 100/100
# 23/23 [==============================] - 1s 58ms/step - loss: 5.3987e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0030 - val_mean_absolute_error: 0.0399

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 4s 29ms/step
# array([[0.6780409 , 0.66789675],
#        [0.5979269 , 0.5969172 ],
#        [0.59578454, 0.5929126 ],
#        [0.5949346 , 0.59079313],
#        [0.60117   , 0.59575796]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[544.7543 , 539.64984],
#        [508.0276 , 507.15466],
#        [507.0455 , 505.32132],
#        [506.65585, 504.351  ],
#        [509.51434, 506.62396]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df1 = pd.concat([df.iloc[-202:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-202:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df1[['Open','Close']] = MMS.inverse_transform(df1[['Open','Close']])
df1.head()
# Out:
#                   Open       Close  open_predicted  close_predicted
# Date
# 2021-04-21  508.000000  508.899994      544.754272       539.649841
# 2021-04-22  513.820007  508.779999      508.027588       507.154663
# 2021-04-23  509.010010  505.549988      507.045502       505.321320
# 2021-04-26  506.760010  510.299988      506.655853       504.351013
# 2021-04-27  512.619995  505.549988      509.514343       506.623962

# %%
# plotting the actual open and predicted open prices on date index
df1[['Open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df1[['Close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index 

df2 = pd.concat([df1,pd.DataFrame(columns=df1.columns,
                                        index=pd.date_range(start=df1.index[-1], periods=11, freq='D'))],axis=0)
df2['2022-02-03':'2022-02-21']
# Out:
#                   Open       Close  open_predicted  close_predicted
# 2022-02-03  421.440002  405.600006      459.262604       461.920654
# 2022-02-04  407.309998  410.170013      431.650848       438.466675
# 2022-02-04         NaN         NaN             NaN              NaN
# 2022-02-05         NaN         NaN             NaN              NaN
# 2022-02-06         NaN         NaN             NaN              NaN
# 2022-02-07         NaN         NaN             NaN              NaN
# 2022-02-08         NaN         NaN             NaN              NaN
# 2022-02-09         NaN         NaN             NaN              NaN
# 2022-02-10         NaN         NaN             NaN              NaN
# 2022-02-11         NaN         NaN             NaN              NaN
# 2022-02-12         NaN         NaN             NaN              NaN
# 2022-02-13         NaN         NaN             NaN              NaN
# 2022-02-14         NaN         NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
forthcoming_prediction = pd.DataFrame(columns=['open','close'],index=df1.index)
forthcoming_prediction.index=pd.to_datetime(forthcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  forthcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 64ms/step

# %%
# inversing Normalization/scaling
forthcoming_prediction[['open','close']] = MMS.inverse_transform(forthcoming_prediction[['open','close']])

# %%
# plotting forthcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df1.loc['2022-01-24':,'Open'],label='Current Open Price')
ax.plot(forthcoming_prediction.loc['2022-01-24':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Forthcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df1.loc['2022-01-24':,'Close'],label='Current close Price')
ax.plot(forthcoming_prediction.loc['2022-01-24':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Forthcoming close price prediction',size=15)
ax.legend()
fig.show()
